# %%
import osmnx as ox
import geopandas as gpd
import pandas as pd

# %matplotlib inline

ox.__version__
# Out:
# '1.6.0'

# %%
neighborhood_info = {
    "Centro",
    "Guadalupe",
    "Frei Rogério",
    "São Cristovão"
}

# %%
for name in neighborhood_info:
    place_name = f"{name}, Lages, Santa Catarina, Brasil"
    neighborhood = ox.geocode_to_gdf(place_name)
    ax = neighborhood_proj.plot(fc="gray", ec="none")
    _ = ax.axis("on")
