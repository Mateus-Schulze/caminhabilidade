# %%
import osmnx as ox
import matplotlib.pyplot as plt
import geopandas as gpd
import pandas as pd

ox.__version__
# Out:
# '1.6.0'

# %%
#INDIVIDUAL
neighborhood_info = ["Centro","Guadalupe"]
tags = {"building" : True}

# %%
for name in neighborhood_info:
    place_name = f"{name}, Lages, Santa Catarina, Brazil"
    neighborhood = ox.features_from_place(place_name, tags=tags)

#PLOT
    fig, ax = plt.subplots()
    neighborhood.plot(ax=ax, fc="none", ec="red")
    ax.set_title(name)
    ax.set_xlabel("Longitude")
    ax.set_ylabel("Latitude")
    ax.axis("on") 

plt.show()

# %%
# PROJEÇÃO EM LAGES
neighborhood_info = {
    "Centro": "red",
    "Guadalupe": "blue",
    "Frei Rojério": "purple",
    "São Cristovão": "green"
}
tags = {"building": True}

# %%
# BAIRROS
combined_neighborhoods = gpd.GeoDataFrame()

# Retrieve and store the neighborhoods' geometries
for name, color in neighborhood_info.items():
    place_name = f"{name}, Lages, Santa Catarina, Brazil"
    neighborhood = ox.features_from_place(place_name, tags=tags)
    neighborhood["color"] = color  # Add a new 'color' column
    combined_neighborhoods = pd.concat([combined_neighborhoods, neighborhood], ignore_index=True)

fig, ax = plt.subplots(figsize=(15, 15))

for color, subset in combined_neighborhoods.groupby("color"):
    subset.plot(ax=ax, fc="none", ec=color)
ax.set_title("bairros combinados")
ax.axis("off")

#plt.savefig("neighborhoods_plot.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
#INDIVIDUAL
neighborhood_info = ["Centro"]
# UNIDADES DE ENSINO
tags = {"amenity" : ["kindergarten", "school", "college", "university"]}

# %%
for name in neighborhood_info:
    place_name = f"{name}, Lages, Santa Catarina, Brazil"
    neighborhood = ox.features_from_place(place_name, tags=tags)

#PLOT
    fig, ax = plt.subplots()
    neighborhood.plot(ax=ax, fc="none", ec="red")
    ax.set_title(name)
    ax.set_xlabel("Longitude")
    ax.set_ylabel("Latitude")
    ax.axis("on") 

plt.show()

# %%
#INDIVIDUAL
neighborhood_info = ["Coral"]
# UNIDADES DE ENSINO
tags = {"highway": "bus_stop"}

# %%
for name in neighborhood_info:
    place_name = f"{name}, Lages, Santa Catarina, Brazil"
    neighborhood = ox.features_from_place(place_name, tags=tags)

#PLOT
    fig, ax = plt.subplots()
    neighborhood.plot(ax=ax, fc="none", ec="red")
    ax.set_title(name)
    ax.set_xlabel("Longitude")
    ax.set_ylabel("Latitude")
    ax.axis("on") 

plt.show()
